# %%
cluster_name = "dp-hadoop-spark-2-cluster-pam"
zone_name = "us-central1-a"


gcloud compute ssh dp-hadoop-spark-2-cluster-pam-m --zone=us-central1-a



gsutil cp gs://scripts_adta5240_project/FindMaxUpzdate.py FindMaxUpzdate.py -- Copy the script to Dataproc



gcloud dataproc jobs submit pyspark gs://your-bucket/scripts/find_max_upzdate.py \
    --cluster=your-cluster-name \
    --region=your-region


spark-submit /home/pranavmoses/scripts/upload_to_table.py


gsutil cp gs://scripts_adta5240_project/upload_to_table.py upload_to_table.py
